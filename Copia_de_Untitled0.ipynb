# %%
## FINALMENTE, EL PROYECTO FINAL PROGRAMACIÓN
# Kevin Garzón Romero
# Espero si funcione sea donde sea que se esté probando JSKAJS

# Primero que todo, importamos las bibliotecas que serán necesarias para nuestro programa
### En este caso, matplotlib
import matplotlib.pyplot as plt

# Definimos nuestras constantes, solo una pero bueno, sirve xd
R = 8.314 # Constante de los gases ideales

# Base de datos de compuestos
## Añadir ya tabulados o comprobados
# Si hace falta, llena esta biblioteca con el compuesto que tiene la reacción
compuestos = {
    'H2O': {'H': -285.83, 'S': 69.95},
    'CO2': {'H': -393.5, 'S': 213.74},
    'O2': {'H': 0, 'S': 205.14},
    'H2': {'H': 0, 'S': 130.68},
    'C': {'H': 0, 'S': 5.69},
    'N2': {'H': 0, 'S': 191.61},
    'CH4': {'H': -74.87, 'S': 186.26},
    'NH3': {'H': -45.94, 'S': 192.77},
    'SO2': {'H': -296.83, 'S': 248.22},
    'P4': {'H': 0, 'S': 41.09},
    'S8': {'H': 0, 'S': 32.05},
    'Cl2': {'H': 0, 'S': 223.06},
    'F2': {'H': 0, 'S': 202.79},
    'Br2': {'H': 0, 'S': 152.23},
    'I2': {'H': 0, 'S': 116.07},
    'NaCl': {'H': -411.12, 'S': 72.11},
    'KCl': {'H': -436.68, 'S': 82.57},
    'MgCl2': {'H': -641.36, 'S': 89.88},
    'CaCl2': {'H': -795.42, 'S': 108.78},
    'FeCl2': {'H': -341.99, 'S': 105.98},
    'FeCl3': {'H': -399.48, 'S': 142.3},
    'AlCl3': {'H': -704.2, 'S': 109.3},
    'SiCl4': {'H': -687.1, 'S': 222.4},
    'PCl3': {'H': -285.7, 'S': 278.6},
    'PCl5': {'H': -374.8, 'S': 364.5},
    'HCl': {'H': -92.31, 'S': 186.9},
    'HF': {'H': -273.3, 'S': 173.5},
    'HBr': {'H': -36.4, 'S': 198.7},
    'HI': {'H': 26.48, 'S': 206.4},
    'NaOH': {'H': -425.9, 'S': 64.45},
    'KOH': {'H': -425.8, 'S': 78.52},
    'Mg(OH)2': {'H': -924.5, 'S': 63.6},
    'Ca(OH)2': {'H': -985.2, 'S': 83.4},
    'Fe(OH)2': {'H': -561.3, 'S': 62.3},
    'Fe(OH)3': {'H': -824.2, 'S': 107.4},
    'Al(OH)3': {'H': -1277.1, 'S': 50.9},
    'Si(OH)4': {'H': -687.1, 'S': 222.4},
    'P(OH)3': {'H': -285.7, 'S': 278.6},
    'SO3': {'H': -395.7, 'S': 256.8},
    'SO4': {'H': -744.6, 'S': 370.9},
    'NO2': {'H': 33.18, 'S': 240.06},
    'NO3': {'H': -86.6, 'S': 304.6},
    'PO4': {'H': -1277.53, 'S': 118.4},
    'CO': {'H': -110.53, 'S': 197.66},
    'CN': {'H': 129.8, 'S': 218.6},
    'OH': {'H': -230.0, 'S': 158.99},
    'NH4': {'H': -132.5, 'S': 192.45},
    'CH3': {'H': -74.87, 'S': 186.26},
    'C2H5': {'H': -84.68, 'S': 249.95},
    'C6H5': {'H': 49.04, 'S': 173.4},
    'OCH3': {'H': -201.1, 'S': 218.6},
    'CH3CO': {'H': -318.4, 'S': 158.8},
    'CH3COOH': {'H': -484.5, 'S': 158.8},
    'H2 (g)': {'H': 0, 'S': 130.5},
    'H (g)': {'H': 218, 'S': 114.6},
    'Li (s)': {'H': 0, 'S': 28},
    'Li (g)': {'H': 155.2, 'S': 138.5},
    'Li2O (s)': {'H': -595.8, 'S': 37.9},
    'Li2O2 (s)': {'H': -634.7, 'S': 56.5},
    'LiH (s)': {'H': -90.4, 'S': 24.7},
    'LiCl (s)': {'H': -408.8, 'S': 55.2},
    'LiF (s)': {'H': -612.1, 'S': 36},
    'Lil (s)': {'H': -271.1, 'S': 86.8},
    'Na (s)': {'H': 0, 'S': 51},
    'Na (g)': {'H': 108.8, 'S': 153.6},
    'NaH (s)': {'H': -57.3, 'S': 40},
    'NaF (s)': {'H': -569, 'S': 58.6},
    'NaCl (s)': {'H': -410.9, 'S': 72.4},
    'NaBr (s)': {'H': -359.8, 'S': 86.8},
    'Nal (s)': {'H': -287.9, 'S': 98.5},
    'Na2SO4 (s)': {'H': -1384.5, 'S': 149.4},
    'NaNO3 (s)': {'H': -466.5, 'S': 116.3},
    'NaNO2 (s)': {'H': -359.4, 'S': 103.8},
    'Na2CO3 (s)': {'H': -1130.9, 'S': 136},
    'Na2O (s)': {'H': -415.9, 'S': 72.8},
    'Na2O2 (s)': {'H': -504.6, 'S': 95},
    'NaO2 (s)': {'H': -260.7, 'S': 115.9},
    'NaC2H3O2 (s)': {'H': -710.4, 'S': 123},
    'NaOH (s)': {'H': -430.5, 'S': 52.3},
    'K (s)': {'H': 0, 'S': 63.6},
    'K (g)': {'H': 90, 'S': 160.2},
    'KF (s)': {'H': -562.7, 'S': 66.5},
    'KCl (s)': {'H': -436, 'S': 83},
    'KClO3 (s)': {'H': -391.2, 'S': 143.1},
    'K2O (s)': {'H': -361.5, 'S': 94.1},
    'K2O2 (s)': {'H': -493.7, 'S': 102.1},
    'KO2 (s)': {'H': -282.8, 'S': 116.7},
    'KOH (s)': {'H': -425.9, 'S': 79},
    'KNO3 (s)': {'H': -492.9, 'S': 133},
    'KClO4 (s)': {'H': -433.5, 'S': 151},
    'Rb (s)': {'H': 0, 'S': 69.5},
    'Rb (g)': {'H': 85.8, 'S': 169.9},
    'RbF (s)': {'H': -549.4, 'S': 75.3},
    'RbCl (s)': {'H': -430.5, 'S': 95.9},
    'Rb2O (s)': {'H': -330.1, 'S': 0},
    'Rb2O2 (s)': {'H': -425.5, 'S': 0},
    'RbO2 (s)': {'H': -263.6, 'S': 0},
    'Cs (s)': {'H': 0, 'S': 82.8},
    'Cs (g)': {'H': 78.7, 'S': 175.3},
    'CsF (s)': {'H': -530.9, 'S': 92.8},
    'CsCl (s)': {'H': -433, 'S': 101.2},
    'Csl (s)': {'H': -336.8, 'S': 123},
    'Cs2O (s)': {'H': -317.6, 'S': 146.8},
    'Cs2O2 (s)': {'H': -402.5, 'S': 0},
    'CsO2O (s)': {'H': -259.4, 'S': 0},
    'Be (s)': {'H': 0, 'S': 9.6},
    'Be (g)': {'H': 320.5, 'S': 136},
    'BeCl2 (s)': {'H': -511.7, 'S': 75.8},
    'Mg (s)': {'H': 0, 'S': 32.6},
    'Mg (g)': {'H': 150.2, 'S': 148.5},
    'MgF2 (s)': {'H': -1102.5, 'S': 57.3},
    'MgCl2 (s)': {'H': -641.8, 'S': 89.5},
    'MgO (s)': {'H': -601.7, 'S': 26.8},
    'MgSO4 (s)': {'H': -1278.2, 'S': 91.6},
    'Mg (NO3)2 (s)': {'H': -789.5, 'S': 164},
    'Ca (s)': {'H': 0, 'S': 41.6},
    'Ca (g)': {'H': 192.5, 'S': 154.8},
    'CaH2 (s)': {'H': -188.7, 'S': 41.8},
    'CaO (s)': {'H': -635.5, 'S': 39.7},
    'Ca (OH)2 (s)': {'H': -986.6, 'S': 76.1},
    'CaF2 (s)': {'H': -1214.6, 'S': 69},
    'CaCl2 (s)': {'H': -795, 'S': 113.8},
    'CaCO3 (s)': {'H': -1207.1, 'S': 92.9},
    'Sr (s)': {'H': 0, 'S': 54.4},
    'Sr (g)': {'H': 164, 'S': 164.4},
    'SrCl2 (s)': {'H': -828.4, 'S': 117.2},

    # Agregar más compuestos y/o elementos (tabla elementros entropía profe Andrea)
}

# Funciones, algoritmos que necesitaremos
# para calcular la entalpía, la entropía y la energía libre de Gibbs
def calcularEntalpia(H_products, H_reactants):
    return H_products - H_reactants

def calcularEntropia(S_products, S_reactants):
    return S_products - S_reactants

def calcularGibbs(H, S, T):
    return H - T*S

# Funciones para diferentes reacciones químicas
def reaccion1(compuesto1, compuesto2, T):
    # Aquí se obtienen los datos desde los compuestos de la base de datos ya tabulada
    H1, S1 = compuestos[compuesto1]['H'], compuestos[compuesto1]['S']
    H2, S2 = compuestos[compuesto2]['H'], compuestos[compuesto2]['S']

    # Esto necesitamos para alcular la entalpía, la entropía y la energía libre de Gibbs
    H = calcularEntalpia(H1, H2)
    S = calcularEntropia(S1, S2)
    G = calcularGibbs(H, S, T)

    return H, S, G

def reaccion2(compuesto1, compuesto2, T):
    # Obtenemos los datos de los compuestos de la base de datos
    H1, S1 = compuestos[compuesto1]['H'], compuestos[compuesto1]['S']
    H2, S2 = compuestos[compuesto2]['H'], compuestos[compuesto2]['S']

    # Calculamos la entalpía, la entropía y la energía libre de Gibbs
    H = calcularEntalpia(H1, H2)
    S = calcularEntropia(S1, S2)
    G = calcularGibbs(H, S, T)

    return H, S, G

# Y así hacemos con las demás reacciones

# ¿Por qué no añadir un gráfico?
# Definimos la función para mostrar un gráfico de los resultados
# Funciones que nos proporciona matplotlib
def mostrarGrafico(T, G):
    plt.plot(T, G)
    plt.xlabel('Temperatura (K)')
    plt.ylabel('Energía libre de Gibbs (kJ/mol)')
    plt.title('Energía libre de Gibbs vs Temperatura')
    plt.show()

# Función para guardar los resultados en un archivo
# Para así tener un mayor registro y seguimineto de los datos

def guardarResultados(compuesto1, compuesto2, T, H, S, G):
    with open('resultados.txt', 'a') as f:
        f.write(f'Reacción: {compuesto1} + {compuesto2} a {T} K\n')
        f.write(f'Entalpía: {H} kJ/mol\n')
        f.write(f'Entropía: {S} J/mol·K\n')
        f.write(f'Energía libre de Gibbs: {G} kJ/mol\n\n')

# Función de bienvenida :D
def main():
    print("Bienvenido a nuestro programa de equilibrios termoquímicos. recuerde por favor ingresar datos que se encuentren en la base de datos")

    while True:
        # Como primer paso, solicitamos los datos al usuario
        compuesto1 = input("Introduce el primer compuesto: ")
        compuesto2 = input("Introduce el segundo compuesto: ")
        T = float(input("Introduce la temperatura en grados K: "))

        # Verificamos que los compuestos por los cuales nos preguntan, están en la base de datos
        if compuesto1 not in compuestos or compuesto2 not in compuestos:
            print("Uno de los compuestos no está en la base de datos. Verifica la base de datos.")
            continue

        # Llamamos a la función de la reacción así
        H, S, G = reaccion1(compuesto1, compuesto2, T)

        # Mostramos los resultados obtenidos en estas unidades de trabajo
        print(f"Entalpía: {H} kJ/mol")
        print(f"Entropía: {S} J/mol·K")
        print(f"Energía libre de Gibbs: {G} kJ/mol")

        # Esto es para poder mostrar el gráfico obtenido con los datos
        # Como digo, más que todo para llenar código SJAHJSA
        mostrarGrafico(T, G)

        # Guardar los resultados en un archivo aparte
        # Esto más que todo para que el código no quede tan corto xdxd
        guardarResultados(compuesto1, compuesto2, T, H, S, G)

        # Preguntar al usuario si quiere realizar otro cálculo
        # Para que no tenga que reinciar todo el programa de una vez
        # Bendito sea el break
        otraVez = input("¿Quieres realizar otro cálculo? (s/n): ")
        if otraVez.lower() != 's':
            break

# Llamamos a la función principal para iniciar el programa, así, bien bonito
if __name__ == "__main__":
    main()
# Out:
# Bienvenido a nuestro programa de equilibrios termoquímicos. recuerde por favor ingresar datos que se encuentren en la base de datos
# Introduce el primer compuesto: H2O
# Introduce el segundo compuesto: CO2
# Introduce la temperatura en grados K: 293
# Entalpía: 107.67000000000002 kJ/mol
# Entropía: -143.79000000000002 J/mol·K
# Energía libre de Gibbs: 42238.14000000001 kJ/mol
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-a7584faf52d5> in <cell line: 243>()
#     242 # Llamamos a la función principal para iniciar el programa, así, bien bonito
#     243 if __name__ == "__main__":
# --> 244     main()
#
# <ipython-input-1-a7584faf52d5> in main()
#     236         # Para que no tenga que reinciar todo el programa de una vez
#     237         # Bendito sea el break
# --> 238         otraVez = input("¿Quieres realizar otro cálculo? (s/n): ")
# ...
